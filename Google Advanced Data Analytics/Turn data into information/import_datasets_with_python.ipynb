# %%
# Paso 1: Conectar (montar) tu Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Paso 2: Importar Pandas y leer el archivo

import pandas as pd

# Define la ruta exacta en tu Drive

file_path = '/content/drive/MyDrive/Data Analytics/Unicorn_Companies.csv'

# Lee el archivo CSV usando Pandas
df = pd.read_csv(file_path)

# Paso 3: Verificar que el archivo se ha importado correctamente
print(df.head())
